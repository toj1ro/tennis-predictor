# %% [markdown]
# Для обучения модели взял датасет из открытого репозитория https://github.com/JeffSackmann/tennis_atp
# Были взяты игры 1 на 1 среди мужчин.

# %%
import pandas as pd


def combine_atp_datasets():
    all_data = pd.DataFrame()

    for year in range(1968, 2025):
        file = "./DATASETS/atp_matches_" + str(year) + ".csv"

        year_data = pd.read_csv(file)

        year_data['year'] = int(year)

        all_data = pd.concat([all_data, year_data], axis=0)

    return all_data

# %%
def analyze_dataset(df: pd.DataFrame):
    print("=" * 60)
    print("АНАЛИЗ РАЗМЕРНОСТИ ДАТАСЕТА ATP МАТЧЕЙ")
    print("=" * 60)

    # Основные размерности
    n_samples = len(df)
    n_features = len(df.columns)

    print(f"\nОСНОВНЫЕ РАЗМЕРНОСТИ:")
    print(f"   Количество семплов (строк): {n_samples:,}")
    print(f"   Количество признаков (колонок): {n_features}")
    print(f"   Общий размер датасета: {n_samples:,} x {n_features}")

    # Анализ памяти
    memory_usage = df.memory_usage(deep=True).sum()
    print(f"   Использование памяти: {memory_usage / (1024 * 1024):.2f} MB")

    # Общая статистика по пропускам
    total_cells = n_samples * n_features
    total_missing = df.isnull().sum().sum()
    missing_percent = (total_missing / total_cells) * 100
    print(f"   Общее количество пропусков: {total_missing:,} из {total_cells:,} ({missing_percent:.2f}%)")

    # Список всех признаков
    print(f"\nСПИСОК ВСЕХ ПРИЗНАКОВ ({n_features} шт.):")
    print("-" * 60)
    for i, col in enumerate(df.columns, 1):
        dtype = str(df[col].dtype)
        non_null = df[col].count()
        null_count = n_samples - non_null
        null_percent = (null_count / n_samples) * 100
        print(f"{i:2d}. {col:<25} | {dtype:<10} | {non_null:>6,} значений | {null_count:>6,} пропусков ({null_percent:5.1f}%)")

    # Анализ типов данных
    print(f"\nАНАЛИЗ ТИПОВ ДАННЫХ:")
    dtype_counts = df.dtypes.value_counts()
    for dtype, count in dtype_counts.items():
        print(f"   {dtype}: {count} признаков")

    # Анализ пропущенных значений
    print(f"\nАНАЛИЗ ПРОПУЩЕННЫХ ЗНАЧЕНИЙ:")
    missing_data = df.isnull().sum()
    missing_sorted = missing_data.sort_values(ascending=False)

    print(f"   Всего признаков с пропусками: {(missing_data > 0).sum()}")
    print(f"   Топ-10 признаков с наибольшим количеством пропусков:")
    for col, missing_count in missing_sorted.head(10).items():
        if missing_count > 0:
            percent = (missing_count / n_samples) * 100
            print(f"   - {col:<25}: {missing_count:>6,} ({percent:5.1f}%)")

    # Временной период
    if 'year' in df.columns:
        print(f"\nВРЕМЕННОЙ ПЕРИОД:")
        print(f"   Годы: {df['year'].min()} - {df['year'].max()}")
        print(f"   Период: {df['year'].max() - df['year'].min() + 1} лет")

    # Основные статистики для всех типов данных
    print(f"\n" + "=" * 60)
    print("ОСНОВНЫЕ СТАТИСТИКИ ДЛЯ ВСЕХ ПРИЗНАКОВ")
    print("=" * 60)

    stats = df.describe(include='all')

    # Выводим статистики
    print("\nЧИСЛОВЫЕ ПРИЗНАКИ:")
    print("-" * 60)
    numeric_cols = df.select_dtypes(include=['number']).columns
    for col in numeric_cols:
        if col in stats.columns:
            print(f"\n{col}:")
            col_stats = stats[col]
            print(f"  Количество: {col_stats.get('count', 'N/A'):,.0f}")
            print(f"  Среднее: {col_stats.get('mean', 'N/A'):.2f}")
            print(f"  Стд. отклонение: {col_stats.get('std', 'N/A'):.2f}")
            print(f"  Минимум: {col_stats.get('min', 'N/A')}")
            print(f"  25%: {col_stats.get('25%', 'N/A')}")
            print(f"  50% (медиана): {col_stats.get('50%', 'N/A')}")
            print(f"  75%: {col_stats.get('75%', 'N/A')}")
            print(f"  Максимум: {col_stats.get('max', 'N/A')}")

    print(f"\n" + "=" * 60)
    print("КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ:")
    print("-" * 60)
    categorical_cols = df.select_dtypes(include=['object']).columns
    for col in categorical_cols:
        if col in stats.columns:
            print(f"\n{col}:")
            col_stats = stats[col]
            print(f"  Количество: {col_stats.get('count', 'N/A'):,.0f}")
            print(f"  Уникальных значений: {col_stats.get('unique', 'N/A')}")
            print(f"  Наиболее частое: {col_stats.get('top', 'N/A')}")
            print(f"  Частота: {col_stats.get('freq', 'N/A'):,.0f}")

            # Показываем топ-5 наиболее частых значений
            top_values = df[col].value_counts().head(5)
            print(f"  Топ-5 значений:")
            for value, count in top_values.items():
                percent = (count / len(df)) * 100
                print(f"    {value}: {count:,} ({percent:.1f}%)")

    # Дополнительный анализ распределений
    print(f"\n" + "=" * 60)
    print("ДОПОЛНИТЕЛЬНЫЙ АНАЛИЗ РАСПРЕДЕЛЕНИЙ")
    print("=" * 60)

    # Анализ покрытий
    if 'surface' in df.columns:
        print(f"\nРАСПРЕДЕЛЕНИЕ ПО ПОВЕРХНОСТЯМ:")
        surface_counts = df['surface'].value_counts()
        for surface, count in surface_counts.items():
            percent = (count / len(df)) * 100
            print(f"  {surface}: {count:,} матчей ({percent:.1f}%)")

    # Анализ уровней турниров
    if 'tourney_level' in df.columns:
        print(f"\nРАСПРЕДЕЛЕНИЕ ПО УРОВНЯМ ТУРНИРОВ:")
        level_counts = df['tourney_level'].value_counts()
        for level, count in level_counts.items():
            percent = (count / len(df)) * 100
            print(f"  {level}: {count:,} матчей ({percent:.1f}%)")

    # Анализ раундов
    if 'round' in df.columns:
        print(f"\nРАСПРЕДЕЛЕНИЕ ПО РАУНДАМ:")
        round_counts = df['round'].value_counts()
        for round_name, count in round_counts.items():
            percent = (count / len(df)) * 100
            print(f"  {round_name}: {count:,} матчей ({percent:.1f}%)")

    print(f"\n" + "=" * 60)
    print("АНАЛИЗ ЗАВЕРШЕН")
    print("=" * 60)

# %%
all_data_df = combine_atp_datasets()
analyze_dataset(all_data_df)
# Out:
# ============================================================
# АНАЛИЗ РАЗМЕРНОСТИ ДАТАСЕТА ATP МАТЧЕЙ
# ============================================================
#
# ОСНОВНЫЕ РАЗМЕРНОСТИ:
#    Количество семплов (строк): 194,996
#    Количество признаков (колонок): 50
#    Общий размер датасета: 194,996 x 50
#    Использование памяти: 208.85 MB
#    Общее количество пропусков: 2,772,765 из 9,749,800 (28.44%)
#
# СПИСОК ВСЕХ ПРИЗНАКОВ (50 шт.):
# ------------------------------------------------------------
#  1. tourney_id                | object     | 194,996 значений |      0 пропусков (  0.0%)
#  2. tourney_name              | object     | 194,996 значений |      0 пропусков (  0.0%)
#  3. surface                   | object     | 192,006 значений |  2,990 пропусков (  1.5%)
#  4. draw_size                 | float64    | 194,161 значений |    835 пропусков (  0.4%)
#  5. tourney_level             | object     | 194,996 значений |      0 пропусков (  0.0%)
#  6. tourney_date              | int64      | 194,996 значений |      0 пропусков (  0.0%)
#  7. match_num                 | int64      | 194,996 значений |      0 пропусков (  0.0%)
#  8. winner_id                 | int64      | 194,996 значений |      0 пропусков (  0.0%)
#  9. winner_seed               | float64    | 72,220 значений | 122,776 пропусков ( 63.0%)
# 10. winner_entry              | object     | 17,220 значений | 177,776 пропусков ( 91.2%)
# 11. winner_name               | object     | 194,996 значений |      0 пропусков (  0.0%)
# 12. winner_hand               | object     | 194,993 значений |      3 пропусков (  0.0%)
# 13. winner_ht                 | float64    | 178,366 значений | 16,630 пропусков (  8.5%)
# 14. winner_ioc                | object     | 194,988 значений |      8 пропусков (  0.0%)
# 15. winner_age                | float64    | 193,687 значений |  1,309 пропусков (  0.7%)
# 16. loser_id                  | int64      | 194,996 значений |      0 пропусков (  0.0%)
# 17. loser_seed                | float64    | 36,856 значений | 158,140 пропусков ( 81.1%)
# 18. loser_entry               | object     | 29,142 значений | 165,854 пропусков ( 85.1%)
# 19. loser_name                | object     | 194,996 значений |      0 пропусков (  0.0%)
# 20. loser_hand                | object     | 194,985 значений |     11 пропусков (  0.0%)
# 21. loser_ht                  | float64    | 165,802 значений | 29,194 пропусков ( 15.0%)
# 22. loser_ioc                 | object     | 194,924 значений |     72 пропусков (  0.0%)
# 23. loser_age                 | float64    | 190,348 значений |  4,648 пропусков (  2.4%)
# 24. score                     | object     | 194,987 значений |      9 пропусков (  0.0%)
# 25. best_of                   | int64      | 194,996 значений |      0 пропусков (  0.0%)
# 26. round                     | object     | 194,996 значений |      0 пропусков (  0.0%)
# 27. minutes                   | float64    | 95,105 значений | 99,891 пропусков ( 51.2%)
# 28. w_ace                     | float64    | 98,051 значений | 96,945 пропусков ( 49.7%)
# 29. w_df                      | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 30. w_svpt                    | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 31. w_1stIn                   | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 32. w_1stWon                  | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 33. w_2ndWon                  | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 34. w_SvGms                   | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 35. w_bpSaved                 | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 36. w_bpFaced                 | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 37. l_ace                     | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 38. l_df                      | float64    | 98,051 значений | 96,945 пропусков ( 49.7%)
# 39. l_svpt                    | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 40. l_1stIn                   | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 41. l_1stWon                  | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 42. l_2ndWon                  | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 43. l_SvGms                   | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 44. l_bpSaved                 | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 45. l_bpFaced                 | float64    | 98,050 значений | 96,946 пропусков ( 49.7%)
# 46. winner_rank               | float64    | 159,221 значений | 35,775 пропусков ( 18.3%)
# 47. winner_rank_points        | float64    | 111,998 значений | 82,998 пропусков ( 42.6%)
# 48. loser_rank                | float64    | 150,826 значений | 44,170 пропусков ( 22.7%)
# 49. loser_rank_points         | float64    | 110,346 значений | 84,650 пропусков ( 43.4%)
# 50. year                      | int64      | 194,996 значений |      0 пропусков (  0.0%)
#
# АНАЛИЗ ТИПОВ ДАННЫХ:
#    float64: 30 признаков
#    object: 14 признаков
#    int64: 6 признаков
#
# АНАЛИЗ ПРОПУЩЕННЫХ ЗНАЧЕНИЙ:
#    Всего признаков с пропусками: 38
#    Топ-10 признаков с наибольшим количеством пропусков:
#    - winner_entry             : 177,776 ( 91.2%)
#    - loser_entry              : 165,854 ( 85.1%)
#    - loser_seed               : 158,140 ( 81.1%)
#    - winner_seed              : 122,776 ( 63.0%)
#    - minutes                  : 99,891 ( 51.2%)
#    - l_ace                    : 96,946 ( 49.7%)
#    - l_1stWon                 : 96,946 ( 49.7%)
#    - l_1stIn                  : 96,946 ( 49.7%)
#    - l_2ndWon                 : 96,946 ( 49.7%)
#    - l_svpt                   : 96,946 ( 49.7%)
#
# ВРЕМЕННОЙ ПЕРИОД:
#    Годы: 1968 - 2024
#    Период: 57 лет
#
# ============================================================
# ОСНОВНЫЕ СТАТИСТИКИ ДЛЯ ВСЕХ ПРИЗНАКОВ
# ============================================================
#
# ЧИСЛОВЫЕ ПРИЗНАКИ:
# ------------------------------------------------------------
#
# draw_size:
#   Количество: 194,161
#   Среднее: 53.24
#   Стд. отклонение: 36.82
#   Минимум: 2.0
#   25%: 32.0
#   50% (медиана): 32.0
#   75%: 64.0
#   Максимум: 128.0
#
# tourney_date:
#   Количество: 194,996
#   Среднее: 19941901.36
#   Стд. отклонение: 161356.35
#   Минимум: 19671228.0
#   25%: 19800714.0
#   50% (медиана): 19931004.0
#   75%: 20071231.0
#   Максимум: 20241218.0
#
# match_num:
#   Количество: 194,996
#   Среднее: 82.14
#   Стд. отклонение: 113.87
#   Минимум: 1.0
#   25%: 11.0
#   50% (медиана): 26.0
#   75%: 105.0
#   Максимум: 1701.0
#
# winner_id:
#   Количество: 194,996
#   Среднее: 105319.93
#   Стд. отклонение: 16049.73
#   Минимум: 100001.0
#   25%: 100434.0
#   50% (медиана): 101746.0
#   75%: 104098.0
#   Максимум: 212721.0
#
# winner_seed:
#   Количество: 72,220
#   Среднее: 6.34
#   Стд. отклонение: 5.59
#   Минимум: 1.0
#   25%: 2.0
#   50% (медиана): 5.0
#   75%: 8.0
#   Максимум: 35.0
#
# winner_ht:
#   Количество: 178,366
#   Среднее: 184.57
#   Стд. отклонение: 6.78
#   Минимум: 3.0
#   25%: 180.0
#   50% (медиана): 185.0
#   75%: 188.0
#   Максимум: 211.0
#
# winner_age:
#   Количество: 193,687
#   Среднее: 25.68
#   Стд. отклонение: 4.06
#   Минимум: 14.3
#   25%: 22.7
#   50% (медиана): 25.3
#   75%: 28.2
#   Максимум: 58.7
#
# loser_id:
#   Количество: 194,996
#   Среднее: 106464.19
#   Стд. отклонение: 18507.58
#   Минимум: 100001.0
#   25%: 100532.0
#   50% (медиана): 101962.0
#   75%: 104523.0
#   Максимум: 212970.0
#
# loser_seed:
#   Количество: 36,856
#   Среднее: 7.75
#   Стд. отклонение: 6.11
#   Минимум: 1.0
#   25%: 4.0
#   50% (медиана): 6.0
#   75%: 10.0
#   Максимум: 35.0
#
# loser_ht:
#   Количество: 165,802
#   Среднее: 184.32
#   Стд. отклонение: 6.76
#   Минимум: 3.0
#   25%: 180.0
#   50% (медиана): 185.0
#   75%: 188.0
#   Максимум: 211.0
#
# loser_age:
#   Количество: 190,348
#   Среднее: 25.74
#   Стд. отклонение: 4.20
#   Минимум: 14.2
#   25%: 22.7
#   50% (медиана): 25.4
#   75%: 28.4
#   Максимум: 63.6
#
# best_of:
#   Количество: 194,996
#   Среднее: 3.44
#   Стд. отклонение: 0.83
#   Минимум: 1.0
#   25%: 3.0
#   50% (медиана): 3.0
#   75%: 3.0
#   Максимум: 5.0
#
# minutes:
#   Количество: 95,105
#   Среднее: 104.31
#   Стд. отклонение: 39.73
#   Минимум: 0.0
#   25%: 75.0
#   50% (медиана): 97.0
#   75%: 126.0
#   Максимум: 1146.0
#
# w_ace:
#   Количество: 98,051
#   Среднее: 6.55
#   Стд. отклонение: 5.33
#   Минимум: 0.0
#   25%: 3.0
#   50% (медиана): 5.0
#   75%: 9.0
#   Максимум: 113.0
#
# w_df:
#   Количество: 98,050
#   Среднее: 2.72
#   Стд. отклонение: 2.36
#   Минимум: 0.0
#   25%: 1.0
#   50% (медиана): 2.0
#   75%: 4.0
#   Максимум: 26.0
#
# w_svpt:
#   Количество: 98,050
#   Среднее: 78.11
#   Стд. отклонение: 29.48
#   Минимум: 0.0
#   25%: 56.0
#   50% (медиана): 73.0
#   75%: 94.0
#   Максимум: 491.0
#
# w_1stIn:
#   Количество: 98,050
#   Среднее: 47.72
#   Стд. отклонение: 19.20
#   Минимум: 0.0
#   25%: 34.0
#   50% (медиана): 44.0
#   75%: 58.0
#   Максимум: 361.0
#
# w_1stWon:
#   Количество: 98,050
#   Среднее: 35.99
#   Стд. отклонение: 13.82
#   Минимум: 0.0
#   25%: 26.0
#   50% (медиана): 33.0
#   75%: 43.0
#   Максимум: 292.0
#
# w_2ndWon:
#   Количество: 98,050
#   Среднее: 16.69
#   Стд. отклонение: 6.97
#   Минимум: 0.0
#   25%: 12.0
#   50% (медиана): 16.0
#   75%: 21.0
#   Максимум: 82.0
#
# w_SvGms:
#   Количество: 98,050
#   Среднее: 12.41
#   Стд. отклонение: 4.12
#   Минимум: 0.0
#   25%: 9.0
#   50% (медиана): 11.0
#   75%: 15.0
#   Максимум: 90.0
#
# w_bpSaved:
#   Количество: 98,050
#   Среднее: 3.52
#   Стд. отклонение: 3.08
#   Минимум: 0.0
#   25%: 1.0
#   50% (медиана): 3.0
#   75%: 5.0
#   Максимум: 24.0
#
# w_bpFaced:
#   Количество: 98,050
#   Среднее: 5.15
#   Стд. отклонение: 4.06
#   Минимум: 0.0
#   25%: 2.0
#   50% (медиана): 4.0
#   75%: 7.0
#   Максимум: 34.0
#
# l_ace:
#   Количество: 98,050
#   Среднее: 4.86
#   Стд. отклонение: 4.68
#   Минимум: 0.0
#   25%: 2.0
#   50% (медиана): 4.0
#   75%: 7.0
#   Максимум: 103.0
#
# l_df:
#   Количество: 98,051
#   Среднее: 3.46
#   Стд. отклонение: 2.61
#   Минимум: 0.0
#   25%: 2.0
#   50% (медиана): 3.0
#   75%: 5.0
#   Максимум: 26.0
#
# l_svpt:
#   Количество: 98,050
#   Среднее: 80.96
#   Стд. отклонение: 29.41
#   Минимум: 0.0
#   25%: 59.0
#   50% (медиана): 76.0
#   75%: 97.0
#   Максимум: 489.0
#
# l_1stIn:
#   Количество: 98,050
#   Среднее: 48.16
#   Стд. отклонение: 19.37
#   Минимум: 0.0
#   25%: 34.0
#   50% (медиана): 45.0
#   75%: 58.0
#   Максимум: 328.0
#
# l_1stWon:
#   Количество: 98,050
#   Среднее: 32.03
#   Стд. отклонение: 14.44
#   Минимум: 0.0
#   25%: 22.0
#   50% (медиана): 30.0
#   75%: 40.0
#   Максимум: 284.0
#
# l_2ndWon:
#   Количество: 98,050
#   Среднее: 14.96
#   Стд. отклонение: 7.20
#   Минимум: 0.0
#   25%: 10.0
#   50% (медиана): 14.0
#   75%: 19.0
#   Максимум: 101.0
#
# l_SvGms:
#   Количество: 98,050
#   Среднее: 12.21
#   Стд. отклонение: 4.13
#   Минимум: 0.0
#   25%: 9.0
#   50% (медиана): 11.0
#   75%: 15.0
#   Максимум: 91.0
#
# l_bpSaved:
#   Количество: 98,050
#   Среднее: 4.81
#   Стд. отклонение: 3.28
#   Минимум: -6.0
#   25%: 2.0
#   50% (медиана): 4.0
#   75%: 7.0
#   Максимум: 28.0
#
# l_bpFaced:
#   Количество: 98,050
#   Среднее: 8.72
#   Стд. отклонение: 4.13
#   Минимум: 0.0
#   25%: 6.0
#   50% (медиана): 8.0
#   75%: 11.0
#   Максимум: 38.0
#
# winner_rank:
#   Количество: 159,221
#   Среднее: 75.36
#   Стд. отклонение: 121.35
#   Минимум: 1.0
#   25%: 17.0
#   50% (медиана): 45.0
#   75%: 86.0
#   Максимум: 2101.0
#
# winner_rank_points:
#   Количество: 111,998
#   Среднее: 1391.06
#   Стд. отклонение: 1745.29
#   Минимум: 0.0
#   25%: 499.0
#   50% (медиана): 855.0
#   75%: 1556.0
#   Максимум: 16950.0
#
# loser_rank:
#   Количество: 150,826
#   Среднее: 112.85
#   Стд. отклонение: 162.78
#   Минимум: 1.0
#   25%: 36.0
#   50% (медиана): 70.0
#   75%: 118.0
#   Максимум: 2159.0
#
# loser_rank_points:
#   Количество: 110,346
#   Среднее: 875.08
#   Стд. отклонение: 1004.87
#   Минимум: 0.0
#   25%: 369.0
#   50% (медиана): 641.0
#   75%: 1023.0
#   Максимум: 16950.0
#
# year:
#   Количество: 194,996
#   Среднее: 1994.13
#   Стд. отклонение: 16.14
#   Минимум: 1968.0
#   25%: 1980.0
#   50% (медиана): 1993.0
#   75%: 2008.0
#   Максимум: 2024.0
#
# ============================================================
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ:
# ------------------------------------------------------------
#
# tourney_id:
#   Количество: 194,996
#   Уникальных значений: 8463
#   Наиболее частое: 2020-560
#   Частота: 127
#   Топ-5 значений:
#     2020-560: 127 (0.1%)
#     2020-520: 127 (0.1%)
#     1991-520: 127 (0.1%)
#     2020-580: 127 (0.1%)
#     2008-560: 127 (0.1%)
#
# tourney_name:
#   Количество: 194,996
#   Уникальных значений: 4189
#   Наиболее частое: Roland Garros
#   Частота: 7,191
#   Топ-5 значений:
#     Roland Garros: 7,191 (3.7%)
#     Wimbledon: 7,112 (3.6%)
#     US Open: 6,552 (3.4%)
#     Australian Open: 5,923 (3.0%)
#     Miami Masters: 3,230 (1.7%)
#
# surface:
#   Количество: 192,006
#   Уникальных значений: 4
#   Наиболее частое: Hard
#   Частота: 78,287
#   Топ-5 значений:
#     Hard: 78,287 (40.1%)
#     Clay: 69,418 (35.6%)
#     Grass: 23,401 (12.0%)
#     Carpet: 20,900 (10.7%)
#
# tourney_level:
#   Количество: 194,996
#   Уникальных значений: 6
#   Наиболее частое: A
#   Частота: 127,708
#   Топ-5 значений:
#     A: 127,708 (65.5%)
#     G: 27,537 (14.1%)
#     M: 24,303 (12.5%)
#     D: 14,790 (7.6%)
#     F: 594 (0.3%)
#
# winner_entry:
#   Количество: 17,220
#   Уникальных значений: 10
#   Наиболее частое: Q
#   Частота: 10,633
#   Топ-5 значений:
#     Q: 10,633 (5.5%)
#     WC: 5,077 (2.6%)
#     LL: 1,164 (0.6%)
#     PR: 238 (0.1%)
#     SE: 82 (0.0%)
#
# winner_name:
#   Количество: 194,996
#   Уникальных значений: 4384
#   Наиболее частое: Jimmy Connors
#   Частота: 1,279
#   Топ-5 значений:
#     Jimmy Connors: 1,279 (0.7%)
#     Roger Federer: 1,265 (0.6%)
#     Novak Djokovic: 1,139 (0.6%)
#     Rafael Nadal: 1,091 (0.6%)
#     Ivan Lendl: 1,075 (0.6%)
#
# winner_hand:
#   Количество: 194,993
#   Уникальных значений: 4
#   Наиболее частое: R
#   Частота: 164,994
#   Топ-5 значений:
#     R: 164,994 (84.6%)
#     L: 28,055 (14.4%)
#     U: 1,843 (0.9%)
#     A: 101 (0.1%)
#
# winner_ioc:
#   Количество: 194,988
#   Уникальных значений: 131
#   Наиболее частое: USA
#   Частота: 39,799
#   Топ-5 значений:
#     USA: 39,799 (20.4%)
#     ESP: 16,005 (8.2%)
#     AUS: 15,459 (7.9%)
#     FRA: 12,350 (6.3%)
#     GER: 9,339 (4.8%)
#
# loser_entry:
#   Количество: 29,142
#   Уникальных значений: 11
#   Наиболее частое: Q
#   Частота: 17,752
#   Топ-5 значений:
#     Q: 17,752 (9.1%)
#     WC: 8,757 (4.5%)
#     LL: 2,216 (1.1%)
#     PR: 278 (0.1%)
#     SE: 103 (0.1%)
#
# loser_name:
#   Количество: 194,996
#   Уникальных значений: 7429
#   Наиболее частое: Feliciano Lopez
#   Частота: 492
#   Топ-5 значений:
#     Feliciano Lopez: 492 (0.3%)
#     Fernando Verdasco: 448 (0.2%)
#     Fabrice Santoro: 444 (0.2%)
#     John Alexander: 433 (0.2%)
#     Mikhail Youzhny: 423 (0.2%)
#
# loser_hand:
#   Количество: 194,985
#   Уникальных значений: 4
#   Наиболее частое: R
#   Частота: 163,243
#   Топ-5 значений:
#     R: 163,243 (83.7%)
#     L: 25,783 (13.2%)
#     U: 5,819 (3.0%)
#     A: 140 (0.1%)
#
# loser_ioc:
#   Количество: 194,924
#   Уникальных значений: 145
#   Наиболее частое: USA
#   Частота: 36,184
#   Топ-5 значений:
#     USA: 36,184 (18.6%)
#     AUS: 15,349 (7.9%)
#     ESP: 13,940 (7.1%)
#     FRA: 13,157 (6.7%)
#     GER: 10,176 (5.2%)
#
# score:
#   Количество: 194,987
#   Уникальных значений: 23589
#   Наиболее частое: 6-4 6-4
#   Частота: 5,933
#   Топ-5 значений:
#     6-4 6-4: 5,933 (3.0%)
#     6-3 6-4: 5,863 (3.0%)
#     6-3 6-2: 4,457 (2.3%)
#     6-4 6-2: 4,316 (2.2%)
#     6-3 6-3: 4,133 (2.1%)
#
# round:
#   Количество: 194,996
#   Уникальных значений: 10
#   Наиболее частое: R32
#   Частота: 63,202
#   Топ-5 значений:
#     R32: 63,202 (32.4%)
#     R16: 34,006 (17.4%)
#     R64: 33,339 (17.1%)
#     QF: 17,431 (8.9%)
#     RR: 17,375 (8.9%)
#
# ============================================================
# ДОПОЛНИТЕЛЬНЫЙ АНАЛИЗ РАСПРЕДЕЛЕНИЙ
# ============================================================
#
# РАСПРЕДЕЛЕНИЕ ПО ПОВЕРХНОСТЯМ:
#   Hard: 78,287 матчей (40.1%)
#   Clay: 69,418 матчей (35.6%)
#   Grass: 23,401 матчей (12.0%)
#   Carpet: 20,900 матчей (10.7%)
#
# РАСПРЕДЕЛЕНИЕ ПО УРОВНЯМ ТУРНИРОВ:
#   A: 127,708 матчей (65.5%)
#   G: 27,537 матчей (14.1%)
#   M: 24,303 матчей (12.5%)
#   D: 14,790 матчей (7.6%)
#   F: 594 матчей (0.3%)
#   O: 64 матчей (0.0%)
#
# РАСПРЕДЕЛЕНИЕ ПО РАУНДАМ:
#   R32: 63,202 матчей (32.4%)
#   R16: 34,006 матчей (17.4%)
#   R64: 33,339 матчей (17.1%)
#   QF: 17,431 матчей (8.9%)
#   RR: 17,375 матчей (8.9%)
#   R128: 16,040 матчей (8.2%)
#   SF: 8,950 матчей (4.6%)
#   F: 4,558 матчей (2.3%)
#   BR: 63 матчей (0.0%)
#   ER: 32 матчей (0.0%)
#
# ============================================================
# АНАЛИЗ ЗАВЕРШЕН
# ============================================================

# %%
import numpy as np
import matplotlib.pyplot as plt


def plot_boxplots_grid(df, cols=None, ncols=3, figsize_per_plot=(4, 2.5), savepath=None):
    num = df.select_dtypes(include=[np.number])
    if cols is not None:
        num = num[cols]
    if num.shape[1] == 0:
        raise ValueError("Нет числовых колонок для построения.")
    n = num.shape[1]
    nrows = (n + ncols - 1) // ncols
    figsize = (ncols * figsize_per_plot[0], nrows * figsize_per_plot[1])
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize, squeeze=False)

    for i, col in enumerate(num.columns):
        r, c = divmod(i, ncols)
        ax = axes[r][c]
        data = num[col].dropna()
        ax.boxplot(data,
                   vert=False,
                   patch_artist=True,
                   widths=0.6,
                   boxprops=dict(facecolor='lightcoral', color='black'),
                   medianprops=dict(color='yellow', linewidth=2),
                   whiskerprops=dict(color='black'),
                   capprops=dict(color='black'),
                   flierprops=dict(marker='o', markerfacecolor='green', markeredgecolor='black', markersize=6, alpha=0.8))
        ax.set_title(col, fontsize=9)
        ax.grid(axis='x', linestyle='--', alpha=0.3)

    for j in range(n, nrows * ncols):
        r, c = divmod(j, ncols)
        axes[r][c].axis('off')

    plt.tight_layout()
    if savepath:
        plt.savefig(savepath, dpi=150, bbox_inches='tight')
    plt.show()

# %%
plot_boxplots_grid(all_data_df)

# %% [markdown]
# # Ключевые наблюдения
#
# Размер и пропуски: 194,996 строк × 50 колонок; 28.44% ячеек пропущено это существенно, но ожидаемо для исторического теннисного датасета (старые матчи не содержат детальной статистики).
#
# Очень много пропусков в статистиках по матчам (w_*/l_*, minutes) ~49-51% отсутствует. Детальная статистика ведется с внедрения электронного сбора данных.
#
# **winner_entry / loser_entry** почти полностью пусты (91% и 85% пропусков). Значения присутствуют только для небольшого подмножества матчей
#
# #### Ошибки в полях:
#
# **winner_ht и loser_ht** включают значения 3 и 70, однозначно ошибочные записи (скорее всего опечатка).
#
# **minutes** минимум 0 и максимум 1146, 0 может означать неизвестно/отсутствует, а 1146 мин (19 часов) явно ошибка так как самый длинный матч длился 665 минут, все матчи длиннее будем считать не валидными.
#
# **l_bpSaved** минимум −6, отрицательное количество спасённых брейк-поинтов невозможно это ошибка.

# %% [markdown]
# # Очистка данных

# %%
all_data_filtered = all_data_df.dropna(subset=[
    'winner_id', 'loser_id', 'winner_ht', 'loser_ht', 'winner_age', 'loser_age',
    'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon', 'w_SvGms',
    'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt', 'l_1stIn', 'l_1stWon',
    'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced', 'winner_rank',
    'loser_rank', 'winner_rank_points', 'loser_rank_points', 'surface'
])
all_data_filtered = all_data_filtered.reset_index(drop=True)

all_data_filtered = all_data_filtered.drop(columns=['winner_seed', 'winner_entry', 'loser_seed', 'loser_entry'])

all_data_filtered = all_data_filtered.loc[
    (all_data_filtered['winner_ht'] >= 140) &
    (all_data_filtered['loser_ht'] >= 140) &
    (all_data_filtered['minutes'].isna() | (all_data_filtered['minutes'] <= 664)) &
    (all_data_filtered['l_bpSaved'].isna() | (all_data_filtered['l_bpSaved'] >= 0))
    ].reset_index(drop=True)

# %%
analyze_dataset(all_data_filtered)
# Out:
# ============================================================
# АНАЛИЗ РАЗМЕРНОСТИ ДАТАСЕТА ATP МАТЧЕЙ
# ============================================================
#
# ОСНОВНЫЕ РАЗМЕРНОСТИ:
#    Количество семплов (строк): 95,367
#    Количество признаков (колонок): 46
#    Общий размер датасета: 95,367 x 46
#    Использование памяти: 93.67 MB
#    Общее количество пропусков: 2,971 из 4,386,882 (0.07%)
#
# СПИСОК ВСЕХ ПРИЗНАКОВ (46 шт.):
# ------------------------------------------------------------
#  1. tourney_id                | object     | 95,367 значений |      0 пропусков (  0.0%)
#  2. tourney_name              | object     | 95,367 значений |      0 пропусков (  0.0%)
#  3. surface                   | object     | 95,367 значений |      0 пропусков (  0.0%)
#  4. draw_size                 | float64    | 95,367 значений |      0 пропусков (  0.0%)
#  5. tourney_level             | object     | 95,367 значений |      0 пропусков (  0.0%)
#  6. tourney_date              | int64      | 95,367 значений |      0 пропусков (  0.0%)
#  7. match_num                 | int64      | 95,367 значений |      0 пропусков (  0.0%)
#  8. winner_id                 | int64      | 95,367 значений |      0 пропусков (  0.0%)
#  9. winner_name               | object     | 95,367 значений |      0 пропусков (  0.0%)
# 10. winner_hand               | object     | 95,367 значений |      0 пропусков (  0.0%)
# 11. winner_ht                 | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 12. winner_ioc                | object     | 95,367 значений |      0 пропусков (  0.0%)
# 13. winner_age                | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 14. loser_id                  | int64      | 95,367 значений |      0 пропусков (  0.0%)
# 15. loser_name                | object     | 95,367 значений |      0 пропусков (  0.0%)
# 16. loser_hand                | object     | 95,367 значений |      0 пропусков (  0.0%)
# 17. loser_ht                  | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 18. loser_ioc                 | object     | 95,367 значений |      0 пропусков (  0.0%)
# 19. loser_age                 | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 20. score                     | object     | 95,367 значений |      0 пропусков (  0.0%)
# 21. best_of                   | int64      | 95,367 значений |      0 пропусков (  0.0%)
# 22. round                     | object     | 95,367 значений |      0 пропусков (  0.0%)
# 23. minutes                   | float64    | 92,396 значений |  2,971 пропусков (  3.1%)
# 24. w_ace                     | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 25. w_df                      | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 26. w_svpt                    | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 27. w_1stIn                   | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 28. w_1stWon                  | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 29. w_2ndWon                  | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 30. w_SvGms                   | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 31. w_bpSaved                 | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 32. w_bpFaced                 | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 33. l_ace                     | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 34. l_df                      | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 35. l_svpt                    | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 36. l_1stIn                   | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 37. l_1stWon                  | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 38. l_2ndWon                  | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 39. l_SvGms                   | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 40. l_bpSaved                 | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 41. l_bpFaced                 | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 42. winner_rank               | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 43. winner_rank_points        | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 44. loser_rank                | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 45. loser_rank_points         | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 46. year                      | int64      | 95,367 значений |      0 пропусков (  0.0%)
#
# АНАЛИЗ ТИПОВ ДАННЫХ:
#    float64: 28 признаков
#    object: 12 признаков
#    int64: 6 признаков
#
# АНАЛИЗ ПРОПУЩЕННЫХ ЗНАЧЕНИЙ:
#    Всего признаков с пропусками: 1
#    Топ-10 признаков с наибольшим количеством пропусков:
#    - minutes                  :  2,971 (  3.1%)
#
# ВРЕМЕННОЙ ПЕРИОД:
#    Годы: 1991 - 2024
#    Период: 34 лет
#
# ============================================================
# ОСНОВНЫЕ СТАТИСТИКИ ДЛЯ ВСЕХ ПРИЗНАКОВ
# ============================================================
#
# ЧИСЛОВЫЕ ПРИЗНАКИ:
# ------------------------------------------------------------
#
# draw_size:
#   Количество: 95,367
#   Среднее: 58.54
#   Стд. отклонение: 37.70
#   Минимум: 2.0
#   25%: 32.0
#   50% (медиана): 32.0
#   75%: 64.0
#   Максимум: 128.0
#
# tourney_date:
#   Количество: 95,367
#   Среднее: 20068945.44
#   Стд. отклонение: 98792.55
#   Минимум: 19910107.0
#   25%: 19980720.0
#   50% (медиана): 20061009.0
#   75%: 20151005.0
#   Максимум: 20241218.0
#
# match_num:
#   Количество: 95,367
#   Среднее: 86.63
#   Стд. отклонение: 121.01
#   Минимум: 1.0
#   25%: 14.0
#   50% (медиана): 28.0
#   75%: 112.0
#   Максимум: 1701.0
#
# winner_id:
#   Количество: 95,367
#   Среднее: 108482.53
#   Стд. отклонение: 19801.79
#   Минимум: 100284.0
#   25%: 102223.0
#   50% (медиана): 103786.0
#   75%: 104925.0
#   Максимум: 212063.0
#
# winner_ht:
#   Количество: 95,367
#   Среднее: 185.94
#   Стд. отклонение: 6.73
#   Минимум: 168.0
#   25%: 183.0
#   50% (медиана): 185.0
#   75%: 190.0
#   Максимум: 211.0
#
# winner_age:
#   Количество: 95,367
#   Среднее: 25.94
#   Стд. отклонение: 3.81
#   Минимум: 15.8
#   25%: 23.1
#   50% (медиана): 25.7
#   75%: 28.4
#   Максимум: 42.3
#
# loser_id:
#   Количество: 95,367
#   Среднее: 108318.06
#   Стд. отклонение: 19426.47
#   Минимум: 100282.0
#   25%: 102202.0
#   50% (медиана): 103694.0
#   75%: 105028.0
#   Максимум: 212082.0
#
# loser_ht:
#   Количество: 95,367
#   Среднее: 185.35
#   Стд. отклонение: 6.66
#   Минимум: 160.0
#   25%: 180.0
#   50% (медиана): 185.0
#   75%: 190.0
#   Максимум: 211.0
#
# loser_age:
#   Количество: 95,367
#   Среднее: 26.11
#   Стд. отклонение: 3.89
#   Минимум: 15.4
#   25%: 23.2
#   50% (медиана): 25.9
#   75%: 28.7
#   Максимум: 44.0
#
# best_of:
#   Количество: 95,367
#   Среднее: 3.36
#   Стд. отклонение: 0.77
#   Минимум: 3.0
#   25%: 3.0
#   50% (медиана): 3.0
#   75%: 3.0
#   Максимум: 5.0
#
# minutes:
#   Количество: 92,396
#   Среднее: 104.64
#   Стд. отклонение: 39.44
#   Минимум: 1.0
#   25%: 76.0
#   50% (медиана): 97.0
#   75%: 126.0
#   Максимум: 396.0
#
# w_ace:
#   Количество: 95,367
#   Среднее: 6.59
#   Стд. отклонение: 5.34
#   Минимум: 0.0
#   25%: 3.0
#   50% (медиана): 5.0
#   75%: 9.0
#   Максимум: 75.0
#
# w_df:
#   Количество: 95,367
#   Среднее: 2.72
#   Стд. отклонение: 2.36
#   Минимум: 0.0
#   25%: 1.0
#   50% (медиана): 2.0
#   75%: 4.0
#   Максимум: 26.0
#
# w_svpt:
#   Количество: 95,367
#   Среднее: 78.32
#   Стд. отклонение: 29.51
#   Минимум: 0.0
#   25%: 57.0
#   50% (медиана): 73.0
#   75%: 95.0
#   Максимум: 278.0
#
# w_1stIn:
#   Количество: 95,367
#   Среднее: 47.86
#   Стд. отклонение: 19.21
#   Минимум: 0.0
#   25%: 34.0
#   50% (медиана): 44.0
#   75%: 58.0
#   Максимум: 198.0
#
# w_1stWon:
#   Количество: 95,367
#   Среднее: 36.11
#   Стд. отклонение: 13.83
#   Минимум: 0.0
#   25%: 26.0
#   50% (медиана): 33.0
#   75%: 43.0
#   Максимум: 166.0
#
# w_2ndWon:
#   Количество: 95,367
#   Среднее: 16.73
#   Стд. отклонение: 6.98
#   Минимум: 0.0
#   25%: 12.0
#   50% (медиана): 16.0
#   75%: 21.0
#   Максимум: 65.0
#
# w_SvGms:
#   Количество: 95,367
#   Среднее: 12.44
#   Стд. отклонение: 4.13
#   Минимум: 0.0
#   25%: 9.0
#   50% (медиана): 11.0
#   75%: 15.0
#   Максимум: 49.0
#
# w_bpSaved:
#   Количество: 95,367
#   Среднее: 3.53
#   Стд. отклонение: 3.09
#   Минимум: 0.0
#   25%: 1.0
#   50% (медиана): 3.0
#   75%: 5.0
#   Максимум: 24.0
#
# w_bpFaced:
#   Количество: 95,367
#   Среднее: 5.16
#   Стд. отклонение: 4.06
#   Минимум: 0.0
#   25%: 2.0
#   50% (медиана): 4.0
#   75%: 7.0
#   Максимум: 34.0
#
# l_ace:
#   Количество: 95,367
#   Среднее: 4.89
#   Стд. отклонение: 4.69
#   Минимум: 0.0
#   25%: 2.0
#   50% (медиана): 4.0
#   75%: 7.0
#   Максимум: 67.0
#
# l_df:
#   Количество: 95,367
#   Среднее: 3.46
#   Стд. отклонение: 2.61
#   Минимум: 0.0
#   25%: 2.0
#   50% (медиана): 3.0
#   75%: 5.0
#   Максимум: 26.0
#
# l_svpt:
#   Количество: 95,367
#   Среднее: 81.14
#   Стд. отклонение: 29.44
#   Минимум: 0.0
#   25%: 60.0
#   50% (медиана): 76.0
#   75%: 97.0
#   Максимум: 291.0
#
# l_1stIn:
#   Количество: 95,367
#   Среднее: 48.29
#   Стд. отклонение: 19.39
#   Минимум: 0.0
#   25%: 34.0
#   50% (медиана): 45.0
#   75%: 59.0
#   Максимум: 218.0
#
# l_1stWon:
#   Количество: 95,367
#   Среднее: 32.14
#   Стд. отклонение: 14.44
#   Минимум: 0.0
#   25%: 22.0
#   50% (медиана): 30.0
#   75%: 40.0
#   Максимум: 171.0
#
# l_2ndWon:
#   Количество: 95,367
#   Среднее: 15.00
#   Стд. отклонение: 7.20
#   Минимум: 0.0
#   25%: 10.0
#   50% (медиана): 14.0
#   75%: 19.0
#   Максимум: 66.0
#
# l_SvGms:
#   Количество: 95,367
#   Среднее: 12.24
#   Стд. отклонение: 4.13
#   Минимум: 0.0
#   25%: 9.0
#   50% (медиана): 11.0
#   75%: 15.0
#   Максимум: 50.0
#
# l_bpSaved:
#   Количество: 95,367
#   Среднее: 4.81
#   Стд. отклонение: 3.28
#   Минимум: 0.0
#   25%: 2.0
#   50% (медиана): 4.0
#   75%: 7.0
#   Максимум: 28.0
#
# l_bpFaced:
#   Количество: 95,367
#   Среднее: 8.72
#   Стд. отклонение: 4.14
#   Минимум: 0.0
#   25%: 6.0
#   50% (медиана): 8.0
#   75%: 11.0
#   Максимум: 38.0
#
# winner_rank:
#   Количество: 95,367
#   Среднее: 62.36
#   Стд. отклонение: 77.29
#   Минимум: 1.0
#   25%: 17.0
#   50% (медиана): 43.0
#   75%: 82.0
#   Максимум: 1890.0
#
# winner_rank_points:
#   Количество: 95,367
#   Среднее: 1512.09
#   Стд. отклонение: 1800.37
#   Минимум: 1.0
#   25%: 580.0
#   50% (медиана): 922.0
#   75%: 1680.0
#   Максимум: 16950.0
#
# loser_rank:
#   Количество: 95,367
#   Среднее: 94.15
#   Стд. отклонение: 115.88
#   Минимум: 1.0
#   25%: 35.0
#   50% (медиана): 67.0
#   75%: 109.0
#   Максимум: 2147.0
#
# loser_rank_points:
#   Количество: 95,367
#   Среднее: 943.88
#   Стд. отклонение: 1020.60
#   Минимум: 1.0
#   25%: 438.0
#   50% (медиана): 691.0
#   75%: 1070.0
#   Максимум: 16950.0
#
# year:
#   Количество: 95,367
#   Среднее: 2006.84
#   Стд. отклонение: 9.88
#   Минимум: 1991.0
#   25%: 1998.0
#   50% (медиана): 2006.0
#   75%: 2015.0
#   Максимум: 2024.0
#
# ============================================================
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ:
# ------------------------------------------------------------
#
# tourney_id:
#   Количество: 95,367
#   Уникальных значений: 2742
#   Наиболее частое: 2012-540
#   Частота: 127
#   Топ-5 значений:
#     2012-540: 127 (0.1%)
#     2018-560: 127 (0.1%)
#     2011-540: 127 (0.1%)
#     2012-520: 127 (0.1%)
#     2017-560: 127 (0.1%)
#
# tourney_name:
#   Количество: 95,367
#   Уникальных значений: 589
#   Наиболее частое: Australian Open
#   Частота: 4,193
#   Топ-5 значений:
#     Australian Open: 4,193 (4.4%)
#     Roland Garros: 4,181 (4.4%)
#     Wimbledon: 4,081 (4.3%)
#     US Open: 3,580 (3.8%)
#     Miami Masters: 3,091 (3.2%)
#
# surface:
#   Количество: 95,367
#   Уникальных значений: 4
#   Наиболее частое: Hard
#   Частота: 48,481
#   Топ-5 значений:
#     Hard: 48,481 (50.8%)
#     Clay: 31,348 (32.9%)
#     Grass: 9,943 (10.4%)
#     Carpet: 5,595 (5.9%)
#
# tourney_level:
#   Количество: 95,367
#   Уникальных значений: 6
#   Наиболее частое: A
#   Частота: 58,608
#   Топ-5 значений:
#     A: 58,608 (61.5%)
#     M: 18,457 (19.4%)
#     G: 16,665 (17.5%)
#     D: 1,023 (1.1%)
#     F: 557 (0.6%)
#
# winner_name:
#   Количество: 95,367
#   Уникальных значений: 1505
#   Наиболее частое: Roger Federer
#   Частота: 1,190
#   Топ-5 значений:
#     Roger Federer: 1,190 (1.2%)
#     Novak Djokovic: 1,086 (1.1%)
#     Rafael Nadal: 1,055 (1.1%)
#     Andy Murray: 710 (0.7%)
#     David Ferrer: 702 (0.7%)
#
# winner_hand:
#   Количество: 95,367
#   Уникальных значений: 4
#   Наиболее частое: R
#   Частота: 81,884
#   Топ-5 значений:
#     R: 81,884 (85.9%)
#     L: 13,474 (14.1%)
#     A: 7 (0.0%)
#     U: 2 (0.0%)
#
# winner_ioc:
#   Количество: 95,367
#   Уникальных значений: 90
#   Наиболее частое: ESP
#   Частота: 11,728
#   Топ-5 значений:
#     ESP: 11,728 (12.3%)
#     USA: 11,185 (11.7%)
#     FRA: 8,274 (8.7%)
#     GER: 5,765 (6.0%)
#     ARG: 5,311 (5.6%)
#
# loser_name:
#   Количество: 95,367
#   Уникальных значений: 1919
#   Наиболее частое: Feliciano Lopez
#   Частота: 478
#   Топ-5 значений:
#     Feliciano Lopez: 478 (0.5%)
#     Fernando Verdasco: 440 (0.5%)
#     Andreas Seppi: 406 (0.4%)
#     Mikhail Youzhny: 401 (0.4%)
#     Fabrice Santoro: 398 (0.4%)
#
# loser_hand:
#   Количество: 95,367
#   Уникальных значений: 4
#   Наиболее частое: R
#   Частота: 81,177
#   Топ-5 значений:
#     R: 81,177 (85.1%)
#     L: 14,162 (14.9%)
#     A: 23 (0.0%)
#     U: 5 (0.0%)
#
# loser_ioc:
#   Количество: 95,367
#   Уникальных значений: 93
#   Наиболее частое: USA
#   Частота: 10,382
#   Топ-5 значений:
#     USA: 10,382 (10.9%)
#     ESP: 10,308 (10.8%)
#     FRA: 8,781 (9.2%)
#     GER: 6,369 (6.7%)
#     ARG: 5,327 (5.6%)
#
# score:
#   Количество: 95,367
#   Уникальных значений: 13265
#   Наиболее частое: 6-4 6-4
#   Частота: 3,296
#   Топ-5 значений:
#     6-4 6-4: 3,296 (3.5%)
#     6-3 6-4: 3,293 (3.5%)
#     6-3 6-2: 2,291 (2.4%)
#     6-4 6-2: 2,165 (2.3%)
#     6-4 6-3: 2,091 (2.2%)
#
# round:
#   Количество: 95,367
#   Уникальных значений: 10
#   Наиболее частое: R32
#   Частота: 33,395
#   Топ-5 значений:
#     R32: 33,395 (35.0%)
#     R16: 17,797 (18.7%)
#     R64: 15,850 (16.6%)
#     R128: 10,246 (10.7%)
#     QF: 8,953 (9.4%)
#
# ============================================================
# ДОПОЛНИТЕЛЬНЫЙ АНАЛИЗ РАСПРЕДЕЛЕНИЙ
# ============================================================
#
# РАСПРЕДЕЛЕНИЕ ПО ПОВЕРХНОСТЯМ:
#   Hard: 48,481 матчей (50.8%)
#   Clay: 31,348 матчей (32.9%)
#   Grass: 9,943 матчей (10.4%)
#   Carpet: 5,595 матчей (5.9%)
#
# РАСПРЕДЕЛЕНИЕ ПО УРОВНЯМ ТУРНИРОВ:
#   A: 58,608 матчей (61.5%)
#   M: 18,457 матчей (19.4%)
#   G: 16,665 матчей (17.5%)
#   D: 1,023 матчей (1.1%)
#   F: 557 матчей (0.6%)
#   O: 57 матчей (0.1%)
#
# РАСПРЕДЕЛЕНИЕ ПО РАУНДАМ:
#   R32: 33,395 матчей (35.0%)
#   R16: 17,797 матчей (18.7%)
#   R64: 15,850 матчей (16.6%)
#   R128: 10,246 матчей (10.7%)
#   QF: 8,953 матчей (9.4%)
#   SF: 4,598 матчей (4.8%)
#   F: 2,335 матчей (2.4%)
#   RR: 2,158 матчей (2.3%)
#   ER: 32 матчей (0.0%)
#   BR: 3 матчей (0.0%)
#
# ============================================================
# АНАЛИЗ ЗАВЕРШЕН
# ============================================================

# %%
plot_boxplots_grid(all_data_filtered)

# %% [markdown]
# Записи с большим количеством пропусков или невалидными данными были удалены, так как у нас не временной ряд мы не можем их обработать

# %%
initial_rows = len(all_data_df)
filtered_rows = len(all_data_filtered)

reduction_percent = (initial_rows - filtered_rows) / initial_rows * 100

print(f"Исходный размер датасета: {initial_rows:,} строк")
print(f"После фильтрации осталось: {filtered_rows:,} строк")
print(f"Сокращение: {reduction_percent:.2f}%")
# Out:
# Исходный размер датасета: 194,996 строк
# После фильтрации осталось: 95,367 строк
# Сокращение: 51.09%

# %% [markdown]
# Данные сократились на 51.09%

# %% [markdown]
# # Преобразуем данные

# %% [markdown]
# Теперь преобразуем изначальный датасет в более информативный, для начала объединим признаки проигравшего и победителя в признаки показывающие разницу между ними. К примеру, признаки loser_ht и winner_ht в HEIGHT_DIFF, loser_age и winner_age в AGE_DIFF и т.д.
# Так же были добавлен признак H2H показывающий количество побед\поражений игроков против друг друга и [ELO](https://ru.wikipedia.org/wiki/%D0%A0%D0%B5%D0%B9%D1%82%D0%B8%D0%BD%D0%B3_%D0%AD%D0%BB%D0%BE) метод оценки силы игроков в играх, в основном применяется в шахматах, изначально всем игрокам присваивают 1500 эло после каждого поражения\победы присваивается какое-то количество эло. В тенисе важна поверхность на которой проходит матч, некоторые игроки лучше играют на твердом корте но хуже на траве, поэтому некоторые признаки дублируются относительно поверхности матча.

# %%
from collections import defaultdict


# ---------- utilities ----------
def _infer_stat_basenames(df):
    """
    Возвращает базовые имена статистик в UPPER (ACE, DF, 1ST_IN, ...),
    извлекает по префиксам w_/l_.
    """
    w_cols = [c[2:].upper() for c in df.columns if c.startswith('w_')]
    l_cols = [c[2:].upper() for c in df.columns if c.startswith('l_')]
    basenames = sorted(set(w_cols).intersection(l_cols))
    return basenames


# ---------- long format & rolling ----------
def create_long_format(df, stat_basenames):
    base_cols = ['match_idx', 'tourney_date', 'winner_id', 'loser_id']

    w_cols = [f"w_{s.lower()}" for s in stat_basenames]
    l_cols = [f"l_{s.lower()}" for s in stat_basenames]

    winners = df[base_cols + [c for c in w_cols if c in df.columns]].copy()
    winners = winners.rename(columns={'winner_id': 'player_id', 'loser_id': 'opponent_id'})

    rename_w = {f"w_{s.lower()}": s for s in stat_basenames if f"w_{s.lower()}" in winners.columns}
    winners = winners.rename(columns=rename_w)
    winners['is_winner'] = 1

    losers = df[base_cols + [c for c in l_cols if c in df.columns]].copy()
    losers = losers.rename(columns={'loser_id': 'player_id', 'winner_id': 'opponent_id'})
    rename_l = {f"l_{s.lower()}": s for s in stat_basenames if f"l_{s.lower()}" in losers.columns}
    losers = losers.rename(columns=rename_l)
    losers['is_winner'] = 0

    long = pd.concat([winners, losers], ignore_index=True, sort=False)
    long['tourney_date'] = pd.to_datetime(long['tourney_date'], format='%Y%m%d')
    long = long.sort_values(['player_id', 'tourney_date', 'match_idx']).reset_index(drop=True)
    return long


def compute_rolling_features(long, stat_basenames, windows=(2000,)):
    long = long.copy()

    for s in stat_basenames:
        long[s] = pd.to_numeric(long.get(s, pd.Series(np.nan, index=long.index)), errors='coerce')

    out = long[['match_idx', 'player_id', 'tourney_date']].copy()

    out['games_count'] = long.groupby('player_id').cumcount()

    for w in windows:
        col = f"WIN_LAST_{w}"
        out[col] = (long.groupby('player_id')['is_winner']
                    .transform(lambda x: x.shift().rolling(window=w, min_periods=1).mean()))

    for w in windows:
        for s in stat_basenames:
            col = f"{s}_LAST_{w}"
            out[col] = (long.groupby('player_id')[s]
                        .transform(lambda x: x.shift().rolling(window=w, min_periods=1).mean()))

    return out


# ---------- ELO (global and by-surface) ----------
def compute_elo_pre_match(df, k=42, init_elo=1500):
    elo = defaultdict(lambda: init_elo)
    records = []
    for _, row in df.iterrows():
        idx = row['match_idx']
        p_w = row['winner_id']
        p_l = row['loser_id']
        e_w = elo[p_w]
        e_l = elo[p_l]
        records.append({'match_idx': idx, 'winner_elo_pre': e_w, 'loser_elo_pre': e_l})
        exp_w = 1 / (1 + 10 ** ((e_l - e_w) / 400))
        exp_l = 1 - exp_w
        elo[p_w] = e_w + k * (1 - exp_w)
        elo[p_l] = e_l + k * (0 - exp_l)
    return pd.DataFrame.from_records(records).set_index('match_idx').sort_index()


def compute_elo_pre_match_by_surface(df, k=42, init_elo=1500):
    elo_by_surface = defaultdict(lambda: defaultdict(lambda: init_elo))
    records = []
    for _, row in df.iterrows():
        idx = row['match_idx']
        surface = row.get('surface', 'UNKNOWN')
        p_w = row['winner_id']
        p_l = row['loser_id']
        e_w = elo_by_surface[surface][p_w]
        e_l = elo_by_surface[surface][p_l]
        records.append({
            'match_idx': idx,
            'winner_elo_surface_pre': e_w,
            'loser_elo_surface_pre': e_l,
            'surface': surface
        })
        exp_w = 1 / (1 + 10 ** ((e_l - e_w) / 400))
        elo_by_surface[surface][p_w] = e_w + k * (1 - exp_w)
        elo_by_surface[surface][p_l] = e_l + k * (0 - (1 - exp_w))
    return pd.DataFrame.from_records(records).set_index('match_idx').sort_index()


# ---------- H2H (global & by-surface) ----------
def compute_h2h_prior(df):
    pairs = df[['match_idx', 'tourney_date', 'winner_id', 'loser_id']].copy()
    pairs['p1'] = pairs[['winner_id', 'loser_id']].min(axis=1)
    pairs['p2'] = pairs[['winner_id', 'loser_id']].max(axis=1)
    pairs['p1_win_now'] = (pairs['winner_id'] == pairs['p1']).astype(int)
    pairs = pairs.sort_values('tourney_date')
    groups = pairs.groupby(['p1', 'p2'])
    pairs['p1_wins_prior'] = groups['p1_win_now'].cumsum().shift(1).fillna(0).astype(int)
    pairs['total_prior'] = groups.cumcount()
    return pairs.set_index('match_idx')[['p1', 'p2', 'p1_wins_prior', 'total_prior']].sort_index()


def compute_h2h_by_surface(df):
    pairs = df[['match_idx', 'tourney_date', 'surface', 'winner_id', 'loser_id']].copy()
    pairs['p1'] = pairs[['winner_id', 'loser_id']].min(axis=1)
    pairs['p2'] = pairs[['winner_id', 'loser_id']].max(axis=1)
    pairs['p1_win_now'] = (pairs['winner_id'] == pairs['p1']).astype(int)
    pairs = pairs.sort_values('tourney_date')
    groups = pairs.groupby(['p1', 'p2', 'surface'])
    pairs['p1_wins_surface_prior'] = groups['p1_win_now'].cumsum().shift(1).fillna(0).astype(int)
    pairs['total_surface_prior'] = groups.cumcount()
    return pairs.set_index('match_idx')[['p1', 'p2', 'p1_wins_surface_prior', 'total_surface_prior']].sort_index()


# ---------- ELO gradients ----------
def compute_elo_gradients_from_player_series(df, windows=(5, 10, 20, 35, 50, 100, 250)):
    tmp = df[['match_idx', 'player_id', 'tourney_date', 'PLAYER_ELO_PRE']].copy()
    tmp = tmp.sort_values(['player_id', 'tourney_date', 'match_idx'])
    out = tmp[['match_idx', 'player_id']].copy()
    for w in windows:
        col = f"PLAYER_ELO_GRAD_{w}"
        out[col] = tmp.groupby('player_id')['PLAYER_ELO_PRE'].transform(lambda x: x.diff(w))
    return out


# ---------- main pipeline ----------
def create_normalized_dataset(df,
                              windows=(2000,),
                              elo_grad_windows=(5, 10, 20, 35, 50, 100, 250)):
    df = df.copy()

    rename_map = {}
    for col in df.columns:
        if col.startswith(('w_', 'l_')):
            rename_map[col] = col.lower()
    if rename_map:
        df = df.rename(columns=rename_map)

    df['tourney_date'] = pd.to_datetime(df['tourney_date'], format='%Y%m%d')
    df['match_idx'] = np.arange(len(df))

    np.random.seed(42)

    random_swap = np.random.random(len(df)) < 0.5

    df['PLAYER_1'] = np.where(random_swap, df['winner_id'], df['loser_id'])
    df['PLAYER_2'] = np.where(random_swap, df['loser_id'], df['winner_id'])
    df['RESULT'] = (df['PLAYER_1'] == df['winner_id']).astype(int)

    # ---------- STATIC per-player ----------
    def pick_pair(col_w, col_l):
        p1vals = np.where(df['PLAYER_1'] == df['winner_id'], df.get(col_w, np.nan), df.get(col_l, np.nan))
        p2vals = np.where(df['PLAYER_2'] == df['winner_id'], df.get(col_w, np.nan), df.get(col_l, np.nan))
        return p1vals, p2vals

    p1_points, p2_points = pick_pair('winner_rank_points', 'loser_rank_points')
    df['ATP_POINT_DIFF'] = p1_points - p2_points

    p1_rank, p2_rank = pick_pair('winner_rank', 'loser_rank')

    df['ATP_RANK_DIFF'] = (p2_rank.astype(float)) - (p1_rank.astype(float))

    p1_age, p2_age = pick_pair('winner_age', 'loser_age')
    df['AGE_DIFF'] = p1_age - p2_age

    p1_ht, p2_ht = pick_pair('winner_ht', 'loser_ht')
    df['HEIGHT_DIFF'] = p1_ht - p2_ht

    df['BEST_OF'] = df['best_of'] if 'best_of' in df.columns else np.nan
    df['DRAW_SIZE'] = df['draw_size'] if 'draw_size' in df.columns else np.nan

    # ---------- Rolling stats ----------
    stat_basenames = _infer_stat_basenames(df)
    if len(stat_basenames) > 0:
        long = create_long_format(df, stat_basenames)
        long_feat = compute_rolling_features(long, stat_basenames, windows)

        rolling_cols = [c for c in long_feat.columns if c not in ('match_idx', 'player_id', 'tourney_date')]

        helper = long_feat.copy()

        helper_p1 = helper.rename(columns={'player_id': 'PLAYER_1'})

        helper_p1 = helper_p1.rename(columns={c: f"p1_{c}" for c in rolling_cols})
        df = df.merge(helper_p1, how='left', on=['match_idx', 'PLAYER_1'])

        helper_p2 = helper.rename(columns={'player_id': 'PLAYER_2'})
        helper_p2 = helper_p2.rename(columns={c: f"p2_{c}" for c in rolling_cols})
        df = df.merge(helper_p2, how='left', on=['match_idx', 'PLAYER_2'])

        for c in rolling_cols:
            if c.startswith('WIN_LAST_'):
                for _ in ['WIN_LAST_']: pass

            out_col = f"P_{c}_DIFF"
            p1_col = f"p1_{c}"
            p2_col = f"p2_{c}"
            if p1_col in df.columns and p2_col in df.columns:
                df[out_col] = df[p1_col] - df[p2_col]

        if 'games_count' in rolling_cols and 'p1_games_count' in df.columns and 'p2_games_count' in df.columns:
            df['DIFF_N_GAMES'] = df['p1_games_count'] - df['p2_games_count']

    # ---------- ELO ----------
    elo_df = compute_elo_pre_match(df.sort_values('tourney_date'))
    df = df.merge(elo_df.reset_index(), on='match_idx', how='left')
    df['ELO_P1_PRE'] = np.where(df['PLAYER_1'] == df['winner_id'], df['winner_elo_pre'], df['loser_elo_pre'])
    df['ELO_P2_PRE'] = np.where(df['PLAYER_2'] == df['winner_id'], df['winner_elo_pre'], df['loser_elo_pre'])
    df['ELO_DIFF'] = df['ELO_P1_PRE'] - df['ELO_P2_PRE']

    # ELO by surface
    elo_surf = compute_elo_pre_match_by_surface(df.sort_values('tourney_date'))
    df = df.merge(elo_surf.reset_index()[['match_idx', 'winner_elo_surface_pre', 'loser_elo_surface_pre']], on='match_idx', how='left')
    df['ELO_P1_SURF_PRE'] = np.where(df['PLAYER_1'] == df['winner_id'], df['winner_elo_surface_pre'], df['loser_elo_surface_pre'])
    df['ELO_P2_SURF_PRE'] = np.where(df['PLAYER_2'] == df['winner_id'], df['winner_elo_surface_pre'], df['loser_elo_surface_pre'])
    df['ELO_SURFACE_DIFF'] = df['ELO_P1_SURF_PRE'] - df['ELO_P2_SURF_PRE']

    # ---------- H2H ----------
    h2h = compute_h2h_prior(df.sort_values('tourney_date'))
    df = df.merge(h2h.reset_index(), on='match_idx', how='left')  # p1, p2, p1_wins_prior, total_prior

    df['player1_is_p1'] = (df['PLAYER_1'] == df['p1']).astype(int)
    df['PLAYER1_H2H_WINS_PRIOR'] = np.where(df['player1_is_p1'] == 1, df['p1_wins_prior'], df['total_prior'] - df['p1_wins_prior'])
    df['PLAYER2_H2H_WINS_PRIOR'] = df['total_prior'] - df['PLAYER1_H2H_WINS_PRIOR']
    df['H2H_DIFF'] = df['PLAYER1_H2H_WINS_PRIOR'] - df['PLAYER2_H2H_WINS_PRIOR']

    # H2H by surface
    h2h_surf = compute_h2h_by_surface(df.sort_values('tourney_date'))
    df = df.merge(h2h_surf.reset_index(), on='match_idx', how='left')

    df['PLAYER1_H2H_WINS_SURF_PRIOR'] = np.where(
        df['player1_is_p1'] == 1,
        df['p1_wins_surface_prior'].fillna(0),
        df['total_surface_prior'].fillna(0) - df['p1_wins_surface_prior'].fillna(0)
    )
    df['PLAYER2_H2H_WINS_SURF_PRIOR'] = df['total_surface_prior'].fillna(0) - df['PLAYER1_H2H_WINS_SURF_PRIOR']
    df['H2H_SURFACE_DIFF'] = df['PLAYER1_H2H_WINS_SURF_PRIOR'] - df['PLAYER2_H2H_WINS_SURF_PRIOR']

    # ---------- ELO gradients ----------

    long_elo_p1 = df[['match_idx', 'tourney_date', 'PLAYER_1', 'ELO_P1_PRE']].rename(columns={'PLAYER_1': 'player_id', 'ELO_P1_PRE': 'PLAYER_ELO_PRE'})
    long_elo_p2 = df[['match_idx', 'tourney_date', 'PLAYER_2', 'ELO_P2_PRE']].rename(columns={'PLAYER_2': 'player_id', 'ELO_P2_PRE': 'PLAYER_ELO_PRE'})
    long_elo = pd.concat([long_elo_p1, long_elo_p2], ignore_index=True, sort=False)
    elo_grads = compute_elo_gradients_from_player_series(long_elo, windows=elo_grad_windows)

    df = df.merge(elo_grads.add_suffix('_P1'), how='left', left_on=['match_idx', 'PLAYER_1'], right_on=['match_idx_P1', 'player_id_P1'])

    df = df.merge(elo_grads.add_suffix('_P2'), how='left', left_on=['match_idx', 'PLAYER_2'], right_on=['match_idx_P2', 'player_id_P2'])

    for w in elo_grad_windows:
        grad_p1_col = f"PLAYER_ELO_GRAD_{w}_P1"
        grad_p2_col = f"PLAYER_ELO_GRAD_{w}_P2"
        out_col = f"ELO_GRAD_{w}_DIFF"
        if grad_p1_col in df.columns and grad_p2_col in df.columns:
            df[out_col] = df[grad_p1_col] - df[grad_p2_col]

    # ---------- finalize output ----------

    p_diff_cols = [c for c in df.columns if c.startswith('P_') and c.endswith('_DIFF')]

    out_cols = [
        'match_idx', 'tourney_date', 'PLAYER_1', 'PLAYER_2',
        'ATP_POINT_DIFF', 'ATP_RANK_DIFF', 'AGE_DIFF', 'HEIGHT_DIFF',
        'BEST_OF', 'DRAW_SIZE',
        'H2H_DIFF', 'H2H_SURFACE_DIFF',
        'DIFF_N_GAMES' if 'DIFF_N_GAMES' in df.columns else None,
        'ELO_DIFF', 'ELO_SURFACE_DIFF'
    ]

    out_cols += [f"ELO_GRAD_{w}_DIFF" for w in elo_grad_windows]
    out_cols = [c for c in out_cols if c is not None]
    out_cols += sorted(p_diff_cols)
    out_cols += ['RESULT']

    out_cols = [c for c in out_cols if c in df.columns]
    normalized_df = df[out_cols].copy()

    feature_cols = [c for c in normalized_df.columns if c not in ('match_idx', 'tourney_date', 'PLAYER_1', 'PLAYER_2', 'RESULT')]
    normalized_df[feature_cols] = normalized_df[feature_cols].fillna(0)
    return normalized_df

# %%
normalized_dataset = create_normalized_dataset(all_data_filtered)

# %% [markdown]
# # Анализ посчитанных фитчей

# %%
analyze_dataset(normalized_dataset)
# Out:
# ============================================================
# АНАЛИЗ РАЗМЕРНОСТИ ДАТАСЕТА ATP МАТЧЕЙ
# ============================================================
#
# ОСНОВНЫЕ РАЗМЕРНОСТИ:
#    Количество семплов (строк): 95,367
#    Количество признаков (колонок): 34
#    Общий размер датасета: 95,367 x 34
#    Использование памяти: 24.74 MB
#    Общее количество пропусков: 0 из 3,242,478 (0.00%)
#
# СПИСОК ВСЕХ ПРИЗНАКОВ (34 шт.):
# ------------------------------------------------------------
#  1. match_idx                 | int64      | 95,367 значений |      0 пропусков (  0.0%)
#  2. tourney_date              | datetime64[ns] | 95,367 значений |      0 пропусков (  0.0%)
#  3. PLAYER_1                  | int64      | 95,367 значений |      0 пропусков (  0.0%)
#  4. PLAYER_2                  | int64      | 95,367 значений |      0 пропусков (  0.0%)
#  5. ATP_POINT_DIFF            | float64    | 95,367 значений |      0 пропусков (  0.0%)
#  6. ATP_RANK_DIFF             | float64    | 95,367 значений |      0 пропусков (  0.0%)
#  7. AGE_DIFF                  | float64    | 95,367 значений |      0 пропусков (  0.0%)
#  8. HEIGHT_DIFF               | float64    | 95,367 значений |      0 пропусков (  0.0%)
#  9. BEST_OF                   | int64      | 95,367 значений |      0 пропусков (  0.0%)
# 10. DRAW_SIZE                 | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 11. H2H_DIFF                  | int64      | 95,367 значений |      0 пропусков (  0.0%)
# 12. H2H_SURFACE_DIFF          | int64      | 95,367 значений |      0 пропусков (  0.0%)
# 13. DIFF_N_GAMES              | int64      | 95,367 значений |      0 пропусков (  0.0%)
# 14. ELO_DIFF                  | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 15. ELO_SURFACE_DIFF          | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 16. ELO_GRAD_5_DIFF           | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 17. ELO_GRAD_10_DIFF          | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 18. ELO_GRAD_20_DIFF          | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 19. ELO_GRAD_35_DIFF          | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 20. ELO_GRAD_50_DIFF          | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 21. ELO_GRAD_100_DIFF         | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 22. ELO_GRAD_250_DIFF         | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 23. P_1STIN_LAST_2000_DIFF    | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 24. P_1STWON_LAST_2000_DIFF   | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 25. P_2NDWON_LAST_2000_DIFF   | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 26. P_ACE_LAST_2000_DIFF      | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 27. P_BPFACED_LAST_2000_DIFF  | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 28. P_BPSAVED_LAST_2000_DIFF  | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 29. P_DF_LAST_2000_DIFF       | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 30. P_SVGMS_LAST_2000_DIFF    | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 31. P_SVPT_LAST_2000_DIFF     | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 32. P_WIN_LAST_2000_DIFF      | float64    | 95,367 значений |      0 пропусков (  0.0%)
# 33. P_games_count_DIFF        | int64      | 95,367 значений |      0 пропусков (  0.0%)
# 34. RESULT                    | int64      | 95,367 значений |      0 пропусков (  0.0%)
#
# АНАЛИЗ ТИПОВ ДАННЫХ:
#    float64: 24 признаков
#    int64: 9 признаков
#    datetime64[ns]: 1 признаков
#
# АНАЛИЗ ПРОПУЩЕННЫХ ЗНАЧЕНИЙ:
#    Всего признаков с пропусками: 0
#    Топ-10 признаков с наибольшим количеством пропусков:
#
# ============================================================
# ОСНОВНЫЕ СТАТИСТИКИ ДЛЯ ВСЕХ ПРИЗНАКОВ
# ============================================================
#
# ЧИСЛОВЫЕ ПРИЗНАКИ:
# ------------------------------------------------------------
#
# match_idx:
#   Количество: 95,367
#   Среднее: 47683.00
#   Стд. отклонение: 27530.23
#   Минимум: 0.0
#   25%: 23841.5
#   50% (медиана): 47683.0
#   75%: 71524.5
#   Максимум: 95366.0
#
# PLAYER_1:
#   Количество: 95,367
#   Среднее: 108375.05
#   Стд. отклонение: 19572.76
#   Минимум: 100284.0
#   25%: 102205.0
#   50% (медиана): 103722.0
#   75%: 104999.0
#   Максимум: 212063.0
#
# PLAYER_2:
#   Количество: 95,367
#   Среднее: 108425.53
#   Стд. отклонение: 19657.52
#   Минимум: 100282.0
#   25%: 102205.0
#   50% (медиана): 103737.0
#   75%: 104978.0
#   Максимум: 212082.0
#
# ATP_POINT_DIFF:
#   Количество: 95,367
#   Среднее: -7.53
#   Стд. отклонение: 1911.26
#   Минимум: -16641.0
#   25%: -537.5
#   50% (медиана): -5.0
#   75%: 523.0
#   Максимум: 16516.0
#
# ATP_RANK_DIFF:
#   Количество: 95,367
#   Среднее: -0.81
#   Стд. отклонение: 132.12
#   Минимум: -1876.0
#   25%: -43.0
#   50% (медиана): -1.0
#   75%: 41.0
#   Максимум: 2094.0
#
# AGE_DIFF:
#   Количество: 95,367
#   Среднее: -0.00
#   Стд. отклонение: 5.21
#   Минимум: -21.299999999999997
#   25%: -3.5
#   50% (медиана): 0.0
#   75%: 3.400000000000002
#   Максимум: 25.9
#
# HEIGHT_DIFF:
#   Количество: 95,367
#   Среднее: 0.02
#   Стд. отклонение: 9.26
#   Минимум: -41.0
#   25%: -5.0
#   50% (медиана): 0.0
#   75%: 5.0
#   Максимум: 41.0
#
# BEST_OF:
#   Количество: 95,367
#   Среднее: 3.36
#   Стд. отклонение: 0.77
#   Минимум: 3.0
#   25%: 3.0
#   50% (медиана): 3.0
#   75%: 3.0
#   Максимум: 5.0
#
# DRAW_SIZE:
#   Количество: 95,367
#   Среднее: 58.54
#   Стд. отклонение: 37.70
#   Минимум: 2.0
#   25%: 32.0
#   50% (медиана): 32.0
#   75%: 64.0
#   Максимум: 128.0
#
# H2H_DIFF:
#   Количество: 95,367
#   Среднее: 0.01
#   Стд. отклонение: 3.65
#   Минимум: -55.0
#   25%: -2.0
#   50% (медиана): 0.0
#   75%: 2.0
#   Максимум: 56.0
#
# H2H_SURFACE_DIFF:
#   Количество: 95,367
#   Среднее: 0.01
#   Стд. отклонение: 2.50
#   Минимум: -36.0
#   25%: -2.0
#   50% (медиана): 0.0
#   75%: 2.0
#   Максимум: 38.0
#
# DIFF_N_GAMES:
#   Количество: 95,367
#   Среднее: -1.80
#   Стд. отклонение: 268.71
#   Минимум: -1358.0
#   25%: -133.0
#   50% (медиана): -1.0
#   75%: 128.0
#   Максимум: 1415.0
#
# ELO_DIFF:
#   Количество: 95,367
#   Среднее: -1.34
#   Стд. отклонение: 202.13
#   Минимум: -987.1142785568347
#   25%: -129.12375521420904
#   50% (медиана): -0.625436916341414
#   75%: 125.58651318025068
#   Максимум: 1018.6740362667279
#
# ELO_SURFACE_DIFF:
#   Количество: 95,367
#   Среднее: -1.64
#   Стд. отклонение: 188.56
#   Минимум: -921.0059991067608
#   25%: -113.45571961668259
#   50% (медиана): -0.44848301470619845
#   75%: 109.3814076662411
#   Максимум: 918.5285188799301
#
# ELO_GRAD_5_DIFF:
#   Количество: 95,367
#   Среднее: -0.01
#   Стд. отклонение: 56.69
#   Минимум: -271.0630447306198
#   25%: -35.116245993265125
#   50% (медиана): 0.0
#   75%: 35.0709513544349
#   Максимум: 283.4100163621815
#
# ELO_GRAD_10_DIFF:
#   Количество: 95,367
#   Среднее: -0.16
#   Стд. отклонение: 78.12
#   Минимум: -374.7596293182701
#   25%: -46.47606864651175
#   50% (медиана): 0.0
#   75%: 45.929021325064355
#   Максимум: 350.8437064706868
#
# ELO_GRAD_20_DIFF:
#   Количество: 95,367
#   Среднее: -0.23
#   Стд. отклонение: 100.20
#   Минимум: -570.7471199261597
#   25%: -52.85895162831525
#   50% (медиана): 0.0
#   75%: 52.39354972447131
#   Максимум: 531.9538361716834
#
# ELO_GRAD_35_DIFF:
#   Количество: 95,367
#   Среднее: 0.27
#   Стд. отклонение: 112.27
#   Минимум: -604.0497536229309
#   25%: -45.37105512083076
#   50% (медиана): 0.0
#   75%: 45.54632698574869
#   Максимум: 578.3178262098063
#
# ELO_GRAD_50_DIFF:
#   Количество: 95,367
#   Среднее: -0.14
#   Стд. отклонение: 114.88
#   Минимум: -746.1632535372771
#   25%: -31.246910512889826
#   50% (медиана): 0.0
#   75%: 30.46764873836878
#   Максимум: 648.3856675073109
#
# ELO_GRAD_100_DIFF:
#   Количество: 95,367
#   Среднее: 0.22
#   Стд. отклонение: 110.80
#   Минимум: -839.8611376557642
#   25%: 0.0
#   50% (медиана): 0.0
#   75%: 0.0
#   Максимум: 828.3689425522564
#
# ELO_GRAD_250_DIFF:
#   Количество: 95,367
#   Среднее: 0.01
#   Стд. отклонение: 78.81
#   Минимум: -860.1504797620689
#   25%: 0.0
#   50% (медиана): 0.0
#   75%: 0.0
#   Максимум: 823.6510427278226
#
# P_1STIN_LAST_2000_DIFF:
#   Количество: 95,367
#   Среднее: 0.00
#   Стд. отклонение: 6.84
#   Минимум: -97.0
#   25%: -3.555820529240215
#   50% (медиана): 0.0
#   75%: 3.5361032237710077
#   Максимум: 91.33333333333334
#
# P_1STWON_LAST_2000_DIFF:
#   Количество: 95,367
#   Среднее: -0.01
#   Стд. отклонение: 5.22
#   Минимум: -70.0
#   25%: -2.783699612958344
#   50% (медиана): 0.0
#   75%: 2.7898771702416685
#   Максимум: 61.752066115702476
#
# P_2NDWON_LAST_2000_DIFF:
#   Количество: 95,367
#   Среднее: 0.00
#   Стд. отклонение: 3.18
#   Минимум: -35.041666666666664
#   25%: -1.8677816267685223
#   50% (медиана): 0.0
#   75%: 1.878202467305555
#   Максимум: 31.454780361757106
#
# P_ACE_LAST_2000_DIFF:
#   Количество: 95,367
#   Среднее: -0.00
#   Стд. отклонение: 3.90
#   Минимум: -20.0
#   25%: -2.2291746243952124
#   50% (медиана): 0.0
#   75%: 2.220143683446768
#   Максимум: 37.0
#
# P_BPFACED_LAST_2000_DIFF:
#   Количество: 95,367
#   Среднее: 0.01
#   Стд. отклонение: 1.71
#   Минимум: -17.884057971014492
#   25%: -0.9699845551178252
#   50% (медиана): 0.0
#   75%: 0.9857860530350102
#   Максимум: 21.0
#
# P_BPSAVED_LAST_2000_DIFF:
#   Количество: 95,367
#   Среднее: 0.01
#   Стд. отклонение: 1.02
#   Минимум: -14.148550724637682
#   25%: -0.5085828818754572
#   50% (медиана): 0.0
#   75%: 0.5132673501733014
#   Максимум: 15.994413407821229
#
# P_DF_LAST_2000_DIFF:
#   Количество: 95,367
#   Среднее: 0.00
#   Стд. отклонение: 1.40
#   Минимум: -15.074660633484163
#   25%: -0.807683300908913
#   50% (медиана): 0.0
#   75%: 0.8036844484629295
#   Максимум: 19.5
#
# P_SVGMS_LAST_2000_DIFF:
#   Количество: 95,367
#   Среднее: -0.00
#   Стд. отклонение: 1.26
#   Минимум: -19.0
#   25%: -0.585326417735013
#   50% (медиана): 0.0
#   75%: 0.5857523322208973
#   Максимум: 17.5
#
# P_SVPT_LAST_2000_DIFF:
#   Количество: 95,367
#   Среднее: 0.02
#   Стд. отклонение: 8.81
#   Минимум: -146.35204081632654
#   25%: -3.8541110252731414
#   50% (медиана): 0.0
#   75%: 3.923684556043412
#   Максимум: 128.0
#
# P_WIN_LAST_2000_DIFF:
#   Количество: 95,367
#   Среднее: -0.00
#   Стд. отклонение: 0.18
#   Минимум: -1.0
#   25%: -0.11041754774808646
#   50% (медиана): 0.0
#   75%: 0.10748759087930784
#   Максимум: 1.0
#
# P_games_count_DIFF:
#   Количество: 95,367
#   Среднее: -1.80
#   Стд. отклонение: 268.71
#   Минимум: -1358.0
#   25%: -133.0
#   50% (медиана): -1.0
#   75%: 128.0
#   Максимум: 1415.0
#
# RESULT:
#   Количество: 95,367
#   Среднее: 0.50
#   Стд. отклонение: 0.50
#   Минимум: 0.0
#   25%: 0.0
#   50% (медиана): 0.0
#   75%: 1.0
#   Максимум: 1.0
#
# ============================================================
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ:
# ------------------------------------------------------------
#
# ============================================================
# ДОПОЛНИТЕЛЬНЫЙ АНАЛИЗ РАСПРЕДЕЛЕНИЙ
# ============================================================
#
# ============================================================
# АНАЛИЗ ЗАВЕРШЕН
# ============================================================

# %% [markdown]
# # Анализ корреляций между признаками
# Проверим признаки на корреляции, для этого буду использовать pd.corr() из библиотеки pandas
# по умолчанию там используется корреляция Пирсона.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


def analyze_correlations(df, threshold=0.9):
    print(f"{'=' * 80}")
    print(f"АНАЛИЗ КОРРЕЛЯЦИЙ МЕЖДУ ПРИЗНАКАМИ")
    print(f"{'=' * 80}\n")

    exclude_cols = ['match_idx', 'tourney_date', 'PLAYER_1', 'PLAYER_2', 'RESULT']
    feature_cols = [col for col in df.columns if col not in exclude_cols]

    numeric_features = df[feature_cols].select_dtypes(include=[np.number]).columns.tolist()

    print(f"Всего признаков для анализа: {len(numeric_features)}")
    print(f"Порог сильной корреляции: |r| > {threshold}\n")

    corr_matrix = df[numeric_features].corr()

    high_corr_pairs = []
    for i in range(len(corr_matrix.columns)):
        for j in range(i + 1, len(corr_matrix.columns)):
            corr_val = corr_matrix.iloc[i, j]
            if abs(corr_val) > threshold:
                feat1 = corr_matrix.columns[i]
                feat2 = corr_matrix.columns[j]
                high_corr_pairs.append({
                    'feature_1': feat1,
                    'feature_2': feat2,
                    'correlation': corr_val,
                    'abs_correlation': abs(corr_val)
                })

    if high_corr_pairs:
        high_corr_df = pd.DataFrame(high_corr_pairs).sort_values('abs_correlation', ascending=False)
        print(f"ПРИЗНАКИ С  КОРРЕЛЯЦИЕЙ:")
        print(f"{'=' * 80}\n")

        # Определяем, какие признаки можно удалить
        features_to_remove = set()
        for _, row in high_corr_df.iterrows():
            feat1, feat2 = row['feature_1'], row['feature_2']
            if feat1 not in features_to_remove and feat2 not in features_to_remove:
                count1 = sum(1 for p in high_corr_pairs if feat1 in [p['feature_1'], p['feature_2']])
                count2 = sum(1 for p in high_corr_pairs if feat2 in [p['feature_1'], p['feature_2']])

                if count1 >= count2:
                    features_to_remove.add(feat1)
                    print(f"'{feat1}' коррелирует с '{feat2}', r={row['correlation']:.4f}")
                else:
                    features_to_remove.add(feat2)
                    print(f"'{feat2}' коррелирует с '{feat1}', r={row['correlation']:.4f}")

        print(f"\nВсего признаков к удалению: {len(features_to_remove)}")
        print(f"Останется признаков: {len(numeric_features) - len(features_to_remove)}")
    else:
        print(f"Не найдено пар признаков с корреляцией |r| > {threshold}")

    print(f"\n{'=' * 80}")
    print(f"2. ПОСТРОЕНИЕ HEATMAP")
    print(f"{'=' * 80}\n")

    plt.figure(figsize=(20, 16))

    sns.heatmap(
        corr_matrix,
        annot=False,
        cmap='coolwarm',
        center=0,
        vmin=-1,
        vmax=1,
        square=True,
        linewidths=0.5,
        cbar_kws={"shrink": 0.8, "label": "Корреляция Пирсона"}
    )

    plt.xlabel('Признаки', fontsize=12)
    plt.ylabel('Признаки', fontsize=12)
    plt.xticks(rotation=90, ha='right', fontsize=8)
    plt.yticks(rotation=0, fontsize=8)
    plt.tight_layout()
    plt.show()

    print(f"\n{'=' * 80}")
    print(f"АНАЛИЗ ЗАВЕРШЕН")
    print(f"{'=' * 80}\n")

# %%
analyze_correlations(
    normalized_dataset,
    threshold=0.9,
)
# Out:
# ================================================================================
# АНАЛИЗ КОРРЕЛЯЦИЙ МЕЖДУ ПРИЗНАКАМИ
# ================================================================================
#
# Всего признаков для анализа: 29
# Порог сильной корреляции: |r| > 0.9
#
# ПРИЗНАКИ С  КОРРЕЛЯЦИЕЙ:
# ================================================================================
#
# 'DIFF_N_GAMES' коррелирует с 'P_games_count_DIFF', r=1.0000
# 'P_SVGMS_LAST_2000_DIFF' коррелирует с 'P_SVPT_LAST_2000_DIFF', r=0.9296
# 'P_BPFACED_LAST_2000_DIFF' коррелирует с 'P_BPSAVED_LAST_2000_DIFF', r=0.9113
#
# Всего признаков к удалению: 3
# Останется признаков: 26
#
# ================================================================================
# 2. ПОСТРОЕНИЕ HEATMAP
# ================================================================================
# ================================================================================
# АНАЛИЗ ЗАВЕРШЕН
# ================================================================================

# %% [markdown]
# P_games_count_DIFF дублирует признак DIFF_N_GAMES,
#
# а признаки P_SVGMS_LAST_2000_DIFF и P_BPSAVED_LAST_2000_DIFF сильно коррелируют с P_SVPT_LAST_2000_DIFF и P_BPFACED_LAST_2000_DIFF соответственно,
#
# можно их удалить

# %%
normalized_dataset = normalized_dataset.drop(columns=['P_SVPT_LAST_2000_DIFF', 'P_BPFACED_LAST_2000_DIFF', 'P_games_count_DIFF'])

# %% [markdown]
# # Визулизация через sns.pairplot()

# %%
import seaborn as sns


def visualize_dataset(df, max_samples=2000):
    print(f"\n{'=' * 60}")
    print(f"Визуализация датасета")
    print(f"{'=' * 60}")
    print(f"Исходный размер: {len(df)} строк, {len(df.columns)} признаков")

    df_sample = df.sample(n=min(max_samples, len(df)), random_state=42)
    print(f"Сэмплировано {len(df_sample)} строк для визуализации")

    cols_to_plot = [
        'match_idx',
        'PLAYER_1',
        'PLAYER_2',
        'ELO_DIFF',
        'ATP_RANK_DIFF',
        'P_WIN_LAST_100_DIFF',
        'HEIGHT_DIFF',
        'BEST_OF',
        'RESULT'
    ]

    cols_to_plot = [col for col in cols_to_plot if col in df_sample.columns]

    print(f"\nВыбрано {len(cols_to_plot)} признаков для визуализации:")
    for i, col in enumerate(cols_to_plot, 1):
        print(f"  {i}. {col}")

    print(f"\nСоздание pairplot ({len(cols_to_plot)}×{len(cols_to_plot)} = {len(cols_to_plot) ** 2} графиков)...")

    sns.pairplot(
        df_sample[cols_to_plot],
        hue="RESULT",
        diag_kind='hist',
        plot_kws={
            'alpha': 0.5,
            's': 15,
            'edgecolor': 'none'
        },
        diag_kws={'bins': 30},
        corner=False,
        height=2.0,
    )

    print(f"Готово!")
    print(f"{'=' * 60}\n")

    plt.show()

# %%
visualize_dataset(normalized_dataset)
# Out:
# ============================================================
# Визуализация датасета
# ============================================================
# Исходный размер: 95367 строк, 31 признаков
# Сэмплировано 2000 строк для визуализации
#
# Выбрано 8 признаков для визуализации:
#   1. match_idx
#   2. PLAYER_1
#   3. PLAYER_2
#   4. ELO_DIFF
#   5. ATP_RANK_DIFF
#   6. HEIGHT_DIFF
#   7. BEST_OF
#   8. RESULT
#
# Создание pairplot (8×8 = 64 графиков)...
# Готово!
# ============================================================

# %% [markdown]
# Визуализация показывает что некоторые признаки бесполезны такие как match_idx и id игроков, а ELO и ATP рейтинг хорошо разделяют данные.\
# Примечательно, что разница в росте практически не влияет на исход, хотя во многих активных видах спорта рост бывает ключевым фактором.

# %%
normalized_dataset.to_csv("norm_dataframe.csv")
